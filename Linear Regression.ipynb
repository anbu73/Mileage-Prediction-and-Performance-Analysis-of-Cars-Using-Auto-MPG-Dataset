# %% [markdown]
# Linear Regression - auto dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.linear_model import LinearRegression

# %%
import scipy.stats as sts
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      modelyear  origin                    carname
# 0           70       1  chevrolet chevelle malibu
# ...

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  modelyear  \
# 0  18.0          8         307.0        130    3504          12.0         70
# 1  15.0          8         350.0        165    3693          11.5         70
# 2  18.0          8         318.0        150    3436          11.0         70
# 3  16.0          8         304.0        150    3433          12.0         70
# 4  17.0          8         302.0        140    3449          10.5         70
#
#    origin                    carname
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.shape
# Out:
# (398, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   modelyear     398 non-null    int64
#  7   origin        398 non-null    int64
#  8   carname       398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.isna().apply(pd.value_counts)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\2265488785.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   data.isna().apply(pd.value_counts)
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# False  398        398           398         398     398           398
#
#        modelyear  origin  carname
# False        398     398      398

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#         modelyear      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
sns.histplot(data['mpg'],color='red')
plt.show()

# %%
sns.histplot(data['cylinders'],color='lightblue')
plt.show()

# %%
sns.histplot(data['displacement'],color='green')
plt.show()

# %%
sns.histplot(data['weight'],color='pink')
plt.show()

# %%
sns.histplot(data['acceleration'],color='lightgreen')
plt.show()

# %%
sns.histplot(data['modelyear'],color='purple')
plt.show()

# %%
sns.histplot(data['origin'],color='blue')
plt.show()

# %%
skewness = pd.DataFrame({'Skewness':[sts.skew(data.mpg),sts.skew(data.cylinders),sts.skew(data.displacement),sts.skew(data.weight),sts.skew(data.acceleration),sts.skew(data.modelyear),sts.skew(data.origin)]},index=['mpg','cylinders','displacement','weight','aceleration','modelyear','origin'])
skewness
# Out:
#               Skewness
# mpg           0.455342
# cylinders     0.524934
# displacement  0.716930
# weight        0.529059
# aceleration   0.277725
# modelyear     0.011491
# origin        0.920291

# %%
sns.distplot(data['mpg'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\150098502.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['mpg'])

# %%
sns.distplot(data['cylinders'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\2504101794.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['cylinders'])

# %%
sns.distplot(data['displacement'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\2051734826.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['displacement'])

# %%
sns.distplot(data['weight'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\993834083.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['weight'])

# %%
sns.distplot(data['acceleration'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\2542446549.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['acceleration'])

# %%
sns.distplot(data['modelyear'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\4003480444.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['modelyear'])

# %%
sns.distplot(data['origin'])
plt.show()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7216\810118341.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['origin'])

# %%
sns.boxplot(data['mpg'],color='red')
plt.show()

# %%
sns.boxplot(data['cylinders'],color='lightblue')
plt.show()

# %%
sns.boxplot(data['displacement'],color='green')
plt.show()

# %%
sns.boxplot(data['weight'],color='pink')
plt.show()

# %%
sns.boxplot(data['acceleration'],color='lightgreen')
plt.show()

# %%
sns.boxplot(data['modelyear'],color='purple')
plt.show()

# %%
sns.boxplot(data['origin'],color='blue')
plt.show()

# %%
x1=data.carname.value_counts().index
y1=[data['carname'].value_counts()[j] for j in x1]
plt.xlabel('carname')
plt.ylabel('count')
plt.bar(x1,y1,align='center',color='green',edgecolor='black',alpha=0.7)
# Out:
# <BarContainer object of 305 artists>

# %%
sns.pairplot(data)
plt.show()

# %%
data.drop('modelyear',axis=1,inplace=True)
data.drop('carname',axis=1,inplace=True)

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  origin
# 0    18.0          8         307.0        130    3504          12.0       1
# 1    15.0          8         350.0        165    3693          11.5       1
# 2    18.0          8         318.0        150    3436          11.0       1
# 3    16.0          8         304.0        150    3433          12.0       1
# 4    17.0          8         302.0        140    3449          10.5       1
# ..    ...        ...           ...        ...     ...           ...     ...
# 393  27.0          4         140.0         86    2790          15.6       1
# 394  44.0          4          97.0         52    2130          24.6       2
# 395  32.0          4         135.0         84    2295          11.6       1
# 396  28.0          4         120.0         79    2625          18.6       1
# 397  31.0          4         119.0         82    2720          19.4       1
#
# [398 rows x 7 columns]

# %%
data['origin']=data['origin'].replace({1:['America'],2:['Europe'],3:['Asia']})

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration   origin
# 0  18.0          8         307.0        130    3504          12.0  America
# 1  15.0          8         350.0        165    3693          11.5  America
# 2  18.0          8         318.0        150    3436          11.0  America
# 3  16.0          8         304.0        150    3433          12.0  America
# 4  17.0          8         302.0        140    3449          10.5  America

# %%
data=pd.get_dummies(data,columns=['origin'])
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0  18.0          8         307.0        130    3504          12.0
# 1  15.0          8         350.0        165    3693          11.5
# 2  18.0          8         318.0        150    3436          11.0
# 3  16.0          8         304.0        150    3433          12.0
# 4  17.0          8         302.0        140    3449          10.5
#
#    origin_America  origin_Asia  origin_Europe
# 0            True        False          False
# 1            True        False          False
# 2            True        False          False
# 3            True        False          False
# 4            True        False          False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mpg             398 non-null    float64
#  1   cylinders       398 non-null    int64
#  2   displacement    398 non-null    float64
#  3   horsepower      398 non-null    object
#  4   weight          398 non-null    int64
#  5   acceleration    398 non-null    float64
#  6   origin_America  398 non-null    bool
#  7   origin_Asia     398 non-null    bool
#  8   origin_Europe   398 non-null    bool
# dtypes: bool(3), float64(3), int64(2), object(1)
# memory usage: 20.0+ KB

# %%
h=pd.DataFrame(data.horsepower.str.isdigit())
data[h['horsepower']==False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      origin_America  origin_Asia  origin_Europe
# 32             True        False          False
# 126            True        False          False
# 330           False        False           True
# 336            True        False          False
# 354           False        False           True
# 374            True        False          False

# %%
data=data.replace('?',np.nan)

# %%
data[h['horsepower']==False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0        NaN    2046          19.0
# 126  21.0          6         200.0        NaN    2875          17.0
# 330  40.9          4          85.0        NaN    1835          17.3
# 336  23.6          4         140.0        NaN    2905          14.3
# 354  34.5          4         100.0        NaN    2320          15.8
# 374  23.0          4         151.0        NaN    3035          20.5
#
#      origin_America  origin_Asia  origin_Europe
# 32             True        False          False
# 126            True        False          False
# 330           False        False           True
# 336            True        False          False
# 354           False        False           True
# 374            True        False          False

# %%
medianfiller=lambda x:x.fillna(x.median())
data=data.apply(medianfiller,axis=1)

# %%
data['horsepower']=data['horsepower'].astype('float64')

# %%
sns.pairplot(data)
plt.show()

# %%
x=data.drop('mpg',axis=1)
y=data['mpg']

# %%
x.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  origin_America  \
# 0          8         307.0       130.0    3504          12.0            True
# 1          8         350.0       165.0    3693          11.5            True
# 2          8         318.0       150.0    3436          11.0            True
# 3          8         304.0       150.0    3433          12.0            True
# 4          8         302.0       140.0    3449          10.5            True
#
#    origin_Asia  origin_Europe
# 0        False          False
# 1        False          False
# 2        False          False
# 3        False          False
# 4        False          False

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
for idx,col_name in enumerate(x_train.columns):
    print("The coeff for {0}={1}".format(col_name,model.coef_[idx]))
# Out:
# The coeff for cylinders=-0.5304378374572257
# The coeff for displacement=0.00830943501061188
# The coeff for horsepower=-0.040631176279655457
# The coeff for weight=-0.005449068668580714
# The coeff for acceleration=0.016272000408299542
# The coeff for origin_America=-1.0769623166976174
# The coeff for origin_Asia=1.1822590845388758
# The coeff for origin_Europe=-0.10529676784125853

# %%
print(model.intercept_)
# Out:
# 45.29115580654275

# %%
model.score(x_train,y_train)
# Out:
# 0.6921862749032447

# %%
model.score(x_test,y_test)
# Out:
# 0.7774196746432347
